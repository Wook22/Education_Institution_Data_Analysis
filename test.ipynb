# %% [markdown]
# # Data Analysis on Public Education Dataset

# %%
import pandas as pd

# %%
test_df = pd.read_csv("data/MERGED2021_22_PP.csv")

test_df.head()
# Out:
# /var/folders/nr/wcvbzzhs3kv4kdwf1t2qdjww0000gn/T/ipykernel_67087/3490389120.py:1: DtypeWarning: Columns (9,1725,1726,1727,1728,1729,1743,1815,1816,1817,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1909,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1983,1984,2403,2404,2495,2496,2497,2498,2499,2500,2501,2502,2503,2504,2505,2506,2507,2508,2509,2510,2511,2512,2513,2514,2515,2516,2517,2518,2519,2520,2521,2522,2523,2524,2525,2526,2527,2528,2529,2530) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = pd.read_csv("data/MERGED2021_22_PP.csv")
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# 1  100663   105200.0   1052.0  University of Alabama at Birmingham
# ...

# %%
test_df.columns
# Out:
# Index(['UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'ZIP',
#        'ACCREDAGENCY', 'INSTURL', 'NPCURL',
#        ...
#        'BBRR4_PP_MALE_DISCHARGE', 'BBRR4_PP_NOMALE_N', 'BBRR4_PP_NOMALE_DFLT',
#        'BBRR4_PP_NOMALE_DLNQ', 'BBRR4_PP_NOMALE_FBR', 'BBRR4_PP_NOMALE_DFR',
#        'BBRR4_PP_NOMALE_NOPROG', 'BBRR4_PP_NOMALE_MAKEPROG',
#        'BBRR4_PP_NOMALE_PAIDINFULL', 'BBRR4_PP_NOMALE_DISCHARGE'],
#       dtype='object', length=3214)

# %%
test_df = test_df[[
    "UNITID",
    "INSTNM",
    "STABBR",
    "CITY",
    "ZIP",
    "INSTNM",
    "ADM_RATE",
    "SAT_AVG_ALL",
    "NPT4_PUB",
    "NPT4_PRIV",
    "TUITIONFEE_IN",
    "TUITIONFEE_OUT",
    "LATITUDE",
    "LONGITUDE",
]]


test_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/nr/wcvbzzhs3kv4kdwf1t2qdjww0000gn/T/ipykernel_67087/2709790040.py in <module>
#       7 ]
#       8
# ----> 9 test_df = test_df[column_list]
#      10
#      11 test_df
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %%
test_df.loc[test_df["STABBR"] == "CA"]
# Out:
#                                               INSTNM STABBR
# 163                        Academy of Art University     CA
# 164   Academy of Chinese Culture and Health Sciences     CA
# 165                               College of Alameda     CA
# 166                            Allan Hancock College     CA
# 167    American Academy of Dramatic Arts-Los Angeles     CA
# ...                                              ...    ...
# 6494        High Desert Medical College - Bakerfield     CA
# 6495          High Desert Medical College - Temecula     CA
# 6496     University of West Los Angeles - Chatsworth     CA
# 6513                ABC Adult School - Cabrillo Lane     CA
# 6514                 Urban Barber College - San Jose     CA
#
# [702 rows x 2 columns]
